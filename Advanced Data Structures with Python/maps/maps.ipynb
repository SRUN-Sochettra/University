# %%
from typing import List, Tuple

# Create a new Map
my_map = dict()

# 1. Basic Operations
print("""=== BASIC OPERATIONS ===""")

# Adding key-value pairs
my_map["name"] = "John Doe"
my_map["age"] = 30
my_map["city"] = "New York"
my_map["occupation"] = "Software Engineer"

print(f"Initial Map: {my_map}")
print(f"Size: {len(my_map)}")

# Accessing values
print(f"Name: {my_map['name']}")
print(f"Age: {my_map.get('age')}")

# Updating values
my_map["age"] = 31
print(f"Updated Age: {my_map['age']}")

# Checking existence
print(f"Has 'city': {'city' in my_map}")
print(f"Has 'country': {'country' in my_map}")
# Out:
# === BASIC OPERATIONS ===
# Initial Map: {'name': 'John Doe', 'age': 30, 'city': 'New York', 'occupation': 'Software Engineer'}
# Size: 4
# Name: John Doe
# Age: 30
# Updated Age: 31
# Has 'city': True
# Has 'country': False
